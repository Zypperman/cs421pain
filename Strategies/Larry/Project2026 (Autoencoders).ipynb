# %% [markdown]
# ## AY25-26 Term 2 CS421 Group Project

# %% [markdown]
# ### Data and Task
#
# In this project, you will be working with data extracted from a recommender systems type dataset: you are provided with a large set of interactions between subjects (e.g., online shopping users, or social network users)  and items (e.g., shopping items, books, songs, or movies). Whenever a user "interacts" with an item, he/she has some experience the item (e.g., purchase the items, read the book, listen the songs, or watch the movie) and gives a mark or "rating" between 0 and 5 stars (5 stars indicating the best experience, and 1 or 0 stars indicating that the user didn't like the experience at all).

# %% [markdown]
# In this exercise, we will **not** be performing the recommendation task per se. Instead, we will identify *anomalous users*. In the dataset that you are provided with, some of the data was corrupted. Whilst most of the data comes from real life user-item interactions from a real-world application, some "users" are anomalous: they were generated by me according to some undisclosed procedure to simulate exceptional users with unexpected interactions. Most users have normal, expected interactions in real applications, so the anomalous users only account for a very small proportion of the users. Thus, identifying those anomalous users are important to the application, but it can be very challenging.

# %% [markdown]
# You are provided with two data frames: the first one ("X") contains the interactions provided to you, and the second one ("y") contains the labels for the users. There is a set of 1,000 unique items the users interact with, ranging from item ID of 0 to item ID 999, which is fixed throughout the competition. Note that it is not necessarily that all items appear in one set of data samples given during the competition, meaning that some of the items may not be rated by any user in a user set within a specific period of time.

# %% [markdown]
# As you can see, the three columns in "ratings" correspond to the user ID, the item ID and the rating. Thus, each row of "ratings" contains a single interaction. For instance, if the row "142, 152, 5" is present, this means that the user with ID 142 has given the movie 152 the rating 5 stars.

# %% [markdown]
# The dataframe "labels" has two columns. In the first column we have the user ids, whilst the second column contains the labels. A label of 1 indicates that the user is 'anomalous', whilst a label of 0 denotes a natural, normal user (coming from real life interactions).

# %% [markdown]
# For instance, if the labels matrix contains the line "142, 1", it means that all of the ratings given by the user with id 142 is an anomalous user. This means all lines in the dataframe "ratings" which start with the userID 142 correspond to fake interactions.

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Your task is to be able to classify unseen instances as either anomalies or non anomalies.

# %% [markdown]
# There are **far more** normal users than anomalies in the dataset, which makes this a very heavily **unbalanced dataset**. Thus, accuracy will not be a good measure of performance, since simply predicting that every user is normal will give good accuracy. Thus, we need to use some other evaluation metrics (see slides and lecture note from week 3).

# %% [markdown]
# Suitable **EVALUATION METRICS** include: **AUC** (AREA UNDER CURVE), **PRECISION**, **RECALL**, and **F1 score**. The **main metric** will be the **AREA UNDER CURVE**, and it will by default be used to rank teams. This means your programs should return an **anomaly score** for each user (the higher the score, the more likely the model think the sample is anomalous).

# %% [markdown]
# Before Week 9, each team is required to develop a model using the data `training_data_with_labels.npz` that contains labeled data. You can leverage the data in whatever the way you believe is right. Thereafter every week, we will evaluate the performance of each team's model on an *unseen test set* I will provide, in terms of AUC, and rank the teams by **AUC**. We will release the class labels for the test dataset after we finalize the ranking for each week. Each team then can utilize this newly released class labels (together with the previously released labeled data) to develop a better model.

# %% [markdown]
# The difficulty implied by **the generation procedure of the anomalies WILL CHANGE as the project evolves: depending on how well the teams are doing, I will generate easier or harder anomalies**.

# %% [markdown]
# The **first round of competition** will take place after recess (week 9): this means that I will **release the first test set on the Thursday of week 9**, and you must submit at least one valid set of anomaly scores to **Codabench** before the **Wednesday of week 10 at 11:59 PM**. Your submission will be **a .npz file** (check the exemplar file attached and the code below that generates the .npz file for detail). We will then look at the results together during Thursday's class. Each group will be limited to no more than **THREE submissions per week**. The best result is taken to rank in the leaderboard.
#
# We will check everyone's performance in this way every week (once on  week 10, once on week 11, and once on week 12).
#
# Whilst performance (expressed in terms of AUC and your ranking compared to other teams) at **each of the check points** (weeks 9 to 12 inclusive) is an **important component** of your **final grade**, the **project report** and the detail of the various methods you will have tried will **also** be very **important**. Ideally, to get perfect marks (A+) for this component, you should try at least **two supervised methods** and **one unsupervised methods**, as well as be ranked among the **best teams (top 3)** in terms of performance.
#
# For the project report, I will be especially interested in your analysis and reasoning. High marks will be given to any team that is able to qualitatively and quantitatively analyze the performance of different versions of your models, delivering convincing empirical justification about why the models behave in a particular way. Exemplar qualitative analyses include visualization of feature representations learned in hidden layers, distribution of anomaly scores for the two classes, reasoning over typical failure and correct cases, etc. In terms of quantitative analysis, in addition to general AUC performance of your overall models, other useful quantitative results may include ablation study (i.e., how each component of your model contributes to the overall performance), hyperparameter sensitivity analysis, analysis of computational cost, etc.
#
#
# The performance part of the grading will be based the leaderboard ranking of your group averaged over the three weeks (50% on the first two rounds of ranking, and 50% on the last round of ranking).

# %% [markdown]
# **Leaderboard Instructions**
#
# Create an account on Codabench using your **school email address**. Then, click on the competition link and register for the competition. Once you complete the registration, you will be automatically enrolled in the competition.
#
# **Only one registration per group** is needed; more registration will not be approved, as we rely on the registration to strictly enforce the THREE submissions per week.
#
# **Submision Format**
# 1. Save your predictions as a .npz file
#    The key **must** be named `predictions`, otherwise the scoring program will not be able to read your submission.
#
# 2. Zip the file
# eg. "submission.npz"  →  "submission.zip"
#
# 3. Upload "submission.zip" to Codabench
#
# Competition link : https://www.codabench.org/competitions/14096/
#
# **There's limit on the number of submissions allowed per day and per competition phase, so plan you submissions carefully.
#
# **Phases**
# 1. **Trial Phase.** From now until Wednesday 11.59pm Week 9. Training data is `training_data_with_labels.npz`. Toy test data: `subset_training_batch.npz`, on which you can make prediction and submit the prediction scores. It is for you to get familiar with Codabench.
#
# 2. **Competition Phases.** Each week we release a new test set at Codabench on Thursday (first release will be at week 9).
# - Each group must submit at least one valid set of anomaly scores to Codabench before the Wednesday of subsequent week at 11:59 PM. Your group's ranking will be zero if otherwise.
# - AUC performance of your submitted anomaly scores will be used for leaderboard ranking.
# - The class labels for the test data will be released on `eLearn -> CS421 -> Content -> Group Project` for better training the model for next round
# - Up to **THREE** submissions per week per group.

# %%
MANUAL_TOIGGLE_FOR_COLAB = True
COLAB_TERMINAL = True
LOCAL_TERMINAL = False

# %%
# MAKE SURE TO RUN THIS CELL ONCE ONLY
import os


if MANUAL_TOIGGLE_FOR_COLAB:
    if not os.path.exists("cs421pain"):
        # !git clone https://github.com/Zypperman/cs421pain
    # %cd "cs421pain/ORIGINAL MATS DONT MODIFY"
    train_data_path = !realpath training_batch_with_labels.npz
    tests_data_path = !realpath subset_training_batch.npz
    train_data_path = train_data_path[0]
    tests_data_path = tests_data_path[0]
    # %cd ..
    MANUAL_TOIGGLE_FOR_COLAB = False

if LOCAL_TERMINAL:
    train_data_path = "training_batch_with_labels.npz"
    tests_data_path = "subset_training_batch.npz"

print("train_data_path:", train_data_path)
print("tests_data_path:", tests_data_path)
# Out:
# /content/cs421pain/cs421pain
# train_data_path: /content/cs421pain/cs421pain/ORIGINAL MATS DONT MODIFY/training_batch_with_labels.npz
# tests_data_path: /content/cs421pain/cs421pain/ORIGINAL MATS DONT MODIFY/subset_training_batch.npz

# %%
import numpy as np
import pandas as pd

data = np.load(train_data_path)
test_data = np.load(tests_data_path)

# %%
X=data["X"]
y=data["y"]

print("# of interactions:", X.shape[0])
print("# of anomalous and normal users:", np.count_nonzero(y==1), np.count_nonzero(y==0))


XX=pd.DataFrame(X)
yy=pd.DataFrame(y)
XX.rename(columns={0:"user",1:"item",2:"rating"},inplace=True)
print("# of items:", XX['item'].unique().shape[0])
# Out:
# # of interactions: 177346
# # of anomalous and normal users: 100 1000
# # of items: 993

# %%
XX.head(100)
# Out:
#     user  item  rating
# 0    304     0       3
# 1    304     1       3
# 2    304    14       3
# 3    304    17       4
# 4    304    19       4
# ..   ...   ...     ...
# 95   304   824       3
# 96   304   826       3
# 97   304   828       4
# 98   304   847       3
# 99   304   849       3
#
# [100 rows x 3 columns]

# %%
yy.rename(columns={0:"user",1:"label"},inplace=True)

# %%
yy.head(10)
# Out:
#    user  label
# 0   100      0
# 1   101      0
# 2   102      0
# 3   103      0
# 4   104      0
# 5   105      0
# 6   106      0
# 7   107      0
# 8   108      0
# 9   109      0

# %%
yy.to_csv('ground_truth.csv', index=False, header=False)

# %%
## Example with random scores

data_pred = np.load(tests_data_path)
X_pred = data_pred["X"]
n_users = len(np.unique(X_pred[:, 0]))

# Generate Random Anomaly Scores
np.random.seed(42)
y_score = np.random.uniform(0, 1, size=n_users)  # random float scores between 0 and 1

print(f"# of predictions:     {len(y_score)}")
print(f"Sample scores:        {y_score[:5]}")

## Save as submission.npz
np.savez("submission.npz", predictions=y_score)
print("\nsubmission.npz saved successfully!")
# Out:
# # of predictions:     220
# Sample scores:        [0.37454012 0.95071431 0.73199394 0.59865848 0.15601864]
#
# submission.npz saved successfully!

# %% [markdown]
# # Student Response

# %% [markdown]
# TLDR:
#
# - This is a dataset of user interactions.
# - your job is to find anomalous users based on their current interactions.

# %% [markdown]
# ### Solution 1: Autoencoders
# - turn each user into a 1000-size vector
# - train an autoencoder based on the userbase
# - figure out whether people are weird based on some reconstruction loss function

# %%
NUM_ITEMS = 1000

# . convert interactions into a user-item matrix
# Rows = users (ordered by user_id), Cols = items 0..999, Values = rating (0 = no interaction)
df = pd.DataFrame(X, columns=["user", "item", "rating"])
df_by_user_item = df.pivot_table(index="user", columns="item", values="rating", fill_value=0)

# Reindex columns to guarantee all 1000 items are present, even if some weren't rated
df_by_user_item = df_by_user_item.reindex(columns=range(NUM_ITEMS), fill_value=0)
df_by_user_item_norm = df_by_user_item / 5.0  # Normalize ratings to [0, 1]


# user_ids in order, for aligning with labels
user_ids = df_by_user_item.index.to_numpy()
X_matrix = df_by_user_item.to_numpy(dtype=np.float32)  # shape: (n_users, 1000)

# Normalize ratings to [0, 1]
X_matrix = X_matrix / 5.0

# %%
# . align labels with user_item order
label_df = pd.DataFrame(y, columns=["user", "label"]).set_index("user")
labels = label_df.loc[user_ids, "label"].to_numpy()

# Train only on normal users (label == 0)
X_train = X_matrix[labels == 0]
X_test = X_matrix  # score ALL users at inference

# %%
X_matrix.shape, X_train.shape, X_test.shape, labels.shape
# Out:
# ((1100, 1000), (1000, 1000), (1100, 1000), (1100,))

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import roc_auc_score


class Autoencoder(nn.Module):
    def __init__(self, layer_sizes=[1000, 500, 256, 64]):
        """
        layer_sizes: list of ints defining the encoder architecture.
          e.g. [1000, 500, 256, 64]
          - First value  = input dimension
          - Last value   = latent dimension
          - Middle values = hidden layer widths
          The decoder mirrors this in reverse.
        """
        super().__init__()

        self.layer_sizes = layer_sizes

        encoder_layers = []
        for i in range(len(layer_sizes) - 1):
            encoder_layers.append(nn.Linear(layer_sizes[i], layer_sizes[i + 1]))
            encoder_layers.append(nn.ReLU())
        self.encoder = nn.Sequential(*encoder_layers)

        decoder_layers = []
        reversed_sizes = layer_sizes[::-1]
        for i in range(len(reversed_sizes) - 1):
            decoder_layers.append(nn.Linear(reversed_sizes[i], reversed_sizes[i + 1]))
            if i < len(reversed_sizes) - 2:
                decoder_layers.append(nn.ReLU())
            else:
                decoder_layers.append(nn.Sigmoid())
        self.decoder = nn.Sequential(*decoder_layers)

    def forward(self, x):
        return self.decoder(self.encoder(x))


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Autoencoder(layer_sizes=[1000, 500, 250, 125, 64]).to(device)

train_tensor = torch.tensor(X_train).to(device)
X_test_tensor = torch.tensor(X_test).to(device)
loader = DataLoader(TensorDataset(train_tensor), batch_size=64, shuffle=True)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss(reduction="mean")

if device.type == "cuda":
    print(f"Training device: {device} ({torch.cuda.get_device_name(device)})")
else:
    print(f"Training device: {device}")

prev_loss = None
IMPROVEMENT_THRESHOLD = 0.1  # stop if loss improves by less than 0.01% per epoch
TRIGGER_LIMIT = 3
below_threshold_count = 0


for epoch in range(260):
    # --- train ---
    model.train()
    epoch_loss = 0.0
    for (batch,) in loader:
        recon = model(batch)
        loss = criterion(recon, batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item() * batch.size(0)
    avg_train_loss = epoch_loss / len(train_tensor)

    # --- percentage improvement in train loss from previous epoch ---
    if prev_loss is not None and prev_loss != 0:
        pct_improvement = (prev_loss - avg_train_loss) / prev_loss * 100
        improvement_str = f" | Loss Δ: {pct_improvement:+.2f}%"
    else:
        pct_improvement = None
        improvement_str = " | Loss Δ: N/A"
    prev_loss = avg_train_loss

    # --- eval: per-user reconstruction error as anomaly score ---
    model.eval()
    with torch.no_grad():
        recon_all = model(X_test_tensor)
        scores = ((X_test_tensor - recon_all) ** 2).mean(dim=1).cpu().numpy()

    auc = roc_auc_score(labels, scores)
    print(
        f"Epoch {epoch+1:>3} | Train Loss: {avg_train_loss:.6f}{improvement_str} | AUC: {auc:.4f}"
    )

    if below_threshold_count >= TRIGGER_LIMIT:
        print(
            f"Early stop: loss improvement below threshold "
            f"({IMPROVEMENT_THRESHOLD}%) for {TRIGGER_LIMIT} consecutive epochs."
        )
        break
# Out:
# Training device: cuda (Tesla T4)
# Epoch   1 | Train Loss: 0.151404 | Loss Δ: N/A | AUC: 0.4413
# Epoch   2 | Train Loss: 0.079207 | Loss Δ: +47.68% | AUC: 0.4293
# Epoch   3 | Train Loss: 0.079905 | Loss Δ: -0.88% | AUC: 0.4217
# Epoch   4 | Train Loss: 0.077695 | Loss Δ: +2.77% | AUC: 0.4265
# Epoch   5 | Train Loss: 0.070278 | Loss Δ: +9.55% | AUC: 0.4359
# Epoch   6 | Train Loss: 0.064133 | Loss Δ: +8.74% | AUC: 0.4582
# Epoch   7 | Train Loss: 0.052559 | Loss Δ: +18.05% | AUC: 0.4546
# Epoch   8 | Train Loss: 0.048643 | Loss Δ: +7.45% | AUC: 0.4733
# Epoch   9 | Train Loss: 0.047369 | Loss Δ: +2.62% | AUC: 0.4717
# Epoch  10 | Train Loss: 0.046824 | Loss Δ: +1.15% | AUC: 0.4691
# Epoch  11 | Train Loss: 0.046437 | Loss Δ: +0.83% | AUC: 0.4676
# Epoch  12 | Train Loss: 0.046193 | Loss Δ: +0.53% | AUC: 0.4702
# Epoch  13 | Train Loss: 0.045863 | Loss Δ: +0.72% | AUC: 0.4728
# Epoch  14 | Train Loss: 0.045569 | Loss Δ: +0.64% | AUC: 0.4771
# Epoch  15 | Train Loss: 0.045156 | Loss Δ: +0.91% | AUC: 0.4834
# Epoch  16 | Train Loss: 0.044402 | Loss Δ: +1.67% | AUC: 0.4915
# Epoch  17 | Train Loss: 0.043432 | Loss Δ: +2.19% | AUC: 0.5032
# Epoch  18 | Train Loss: 0.042827 | Loss Δ: +1.39% | AUC: 0.5135
# Epoch  19 | Train Loss: 0.042384 | Loss Δ: +1.03% | AUC: 0.5156
# Epoch  20 | Train Loss: 0.042138 | Loss Δ: +0.58% | AUC: 0.5152
# Epoch  21 | Train Loss: 0.041838 | Loss Δ: +0.71% | AUC: 0.5203
# Epoch  22 | Train Loss: 0.041616 | Loss Δ: +0.53% | AUC: 0.5182
# Epoch  23 | Train Loss: 0.041476 | Loss Δ: +0.34% | AUC: 0.5239
# Epoch  24 | Train Loss: 0.041335 | Loss Δ: +0.34% | AUC: 0.5164
# Epoch  25 | Train Loss: 0.041215 | Loss Δ: +0.29% | AUC: 0.5195
# Epoch  26 | Train Loss: 0.041029 | Loss Δ: +0.45% | AUC: 0.5221
# Epoch  27 | Train Loss: 0.040894 | Loss Δ: +0.33% | AUC: 0.5209
# Epoch  28 | Train Loss: 0.040784 | Loss Δ: +0.27% | AUC: 0.5245
# Epoch  29 | Train Loss: 0.040593 | Loss Δ: +0.47% | AUC: 0.5241
# Epoch  30 | Train Loss: 0.040520 | Loss Δ: +0.18% | AUC: 0.5268
# Epoch  31 | Train Loss: 0.040397 | Loss Δ: +0.30% | AUC: 0.5268
# Epoch  32 | Train Loss: 0.040237 | Loss Δ: +0.39% | AUC: 0.5283
# Epoch  33 | Train Loss: 0.040096 | Loss Δ: +0.35% | AUC: 0.5258
# Epoch  34 | Train Loss: 0.039939 | Loss Δ: +0.39% | AUC: 0.5293
# Epoch  35 | Train Loss: 0.039425 | Loss Δ: +1.29% | AUC: 0.5379
# Epoch  36 | Train Loss: 0.038932 | Loss Δ: +1.25% | AUC: 0.5403
# Epoch  37 | Train Loss: 0.038569 | Loss Δ: +0.93% | AUC: 0.5404
# Epoch  38 | Train Loss: 0.038359 | Loss Δ: +0.54% | AUC: 0.5411
# Epoch  39 | Train Loss: 0.038288 | Loss Δ: +0.19% | AUC: 0.5472
# Epoch  40 | Train Loss: 0.038370 | Loss Δ: -0.22% | AUC: 0.5368
# Epoch  41 | Train Loss: 0.038138 | Loss Δ: +0.60% | AUC: 0.5487
# Epoch  42 | Train Loss: 0.037915 | Loss Δ: +0.58% | AUC: 0.5501
# Epoch  43 | Train Loss: 0.037590 | Loss Δ: +0.86% | AUC: 0.5528
# Epoch  44 | Train Loss: 0.037421 | Loss Δ: +0.45% | AUC: 0.5540
# Epoch  45 | Train Loss: 0.037310 | Loss Δ: +0.30% | AUC: 0.5554
# Epoch  46 | Train Loss: 0.037237 | Loss Δ: +0.20% | AUC: 0.5589
# Epoch  47 | Train Loss: 0.036987 | Loss Δ: +0.67% | AUC: 0.5559
# Epoch  48 | Train Loss: 0.036809 | Loss Δ: +0.48% | AUC: 0.5618
# Epoch  49 | Train Loss: 0.036663 | Loss Δ: +0.40% | AUC: 0.5599
# Epoch  50 | Train Loss: 0.036451 | Loss Δ: +0.58% | AUC: 0.5653
# Epoch  51 | Train Loss: 0.036455 | Loss Δ: -0.01% | AUC: 0.5599
# Epoch  52 | Train Loss: 0.036330 | Loss Δ: +0.34% | AUC: 0.5657
# Epoch  53 | Train Loss: 0.036162 | Loss Δ: +0.46% | AUC: 0.5689
# Epoch  54 | Train Loss: 0.035985 | Loss Δ: +0.49% | AUC: 0.5632
# Epoch  55 | Train Loss: 0.035864 | Loss Δ: +0.34% | AUC: 0.5727
# Epoch  56 | Train Loss: 0.035786 | Loss Δ: +0.22% | AUC: 0.5692
# Epoch  57 | Train Loss: 0.035727 | Loss Δ: +0.16% | AUC: 0.5768
# Epoch  58 | Train Loss: 0.035582 | Loss Δ: +0.40% | AUC: 0.5728
# Epoch  59 | Train Loss: 0.035463 | Loss Δ: +0.33% | AUC: 0.5752
# Epoch  60 | Train Loss: 0.035430 | Loss Δ: +0.09% | AUC: 0.5668
# Epoch  61 | Train Loss: 0.035526 | Loss Δ: -0.27% | AUC: 0.5823
# Epoch  62 | Train Loss: 0.035230 | Loss Δ: +0.83% | AUC: 0.5833
# Epoch  63 | Train Loss: 0.035078 | Loss Δ: +0.43% | AUC: 0.5807
# Epoch  64 | Train Loss: 0.034965 | Loss Δ: +0.32% | AUC: 0.5851
# Epoch  65 | Train Loss: 0.035045 | Loss Δ: -0.23% | AUC: 0.5881
# Epoch  66 | Train Loss: 0.034767 | Loss Δ: +0.79% | AUC: 0.5929
# Epoch  67 | Train Loss: 0.034722 | Loss Δ: +0.13% | AUC: 0.5922
# Epoch  68 | Train Loss: 0.034573 | Loss Δ: +0.43% | AUC: 0.5937
# Epoch  69 | Train Loss: 0.034498 | Loss Δ: +0.22% | AUC: 0.5964
# Epoch  70 | Train Loss: 0.034479 | Loss Δ: +0.05% | AUC: 0.5978
# Epoch  71 | Train Loss: 0.034455 | Loss Δ: +0.07% | AUC: 0.5942
# Epoch  72 | Train Loss: 0.034243 | Loss Δ: +0.62% | AUC: 0.6091
# Epoch  73 | Train Loss: 0.034195 | Loss Δ: +0.14% | AUC: 0.6079
# Epoch  74 | Train Loss: 0.034113 | Loss Δ: +0.24% | AUC: 0.6075
# Epoch  75 | Train Loss: 0.034011 | Loss Δ: +0.30% | AUC: 0.6017
# Epoch  76 | Train Loss: 0.033904 | Loss Δ: +0.32% | AUC: 0.6111
# Epoch  77 | Train Loss: 0.033690 | Loss Δ: +0.63% | AUC: 0.6163
# Epoch  78 | Train Loss: 0.033612 | Loss Δ: +0.23% | AUC: 0.6092
# Epoch  79 | Train Loss: 0.033708 | Loss Δ: -0.28% | AUC: 0.6135
# Epoch  80 | Train Loss: 0.033411 | Loss Δ: +0.88% | AUC: 0.6248
# Epoch  81 | Train Loss: 0.033257 | Loss Δ: +0.46% | AUC: 0.6225
# Epoch  82 | Train Loss: 0.033300 | Loss Δ: -0.13% | AUC: 0.6120
# Epoch  83 | Train Loss: 0.033163 | Loss Δ: +0.41% | AUC: 0.6162
# Epoch  84 | Train Loss: 0.032974 | Loss Δ: +0.57% | AUC: 0.6287
# Epoch  85 | Train Loss: 0.032848 | Loss Δ: +0.38% | AUC: 0.6267
# Epoch  86 | Train Loss: 0.032638 | Loss Δ: +0.64% | AUC: 0.6296
# Epoch  87 | Train Loss: 0.032531 | Loss Δ: +0.33% | AUC: 0.6318
# Epoch  88 | Train Loss: 0.032482 | Loss Δ: +0.15% | AUC: 0.6286
# Epoch  89 | Train Loss: 0.032390 | Loss Δ: +0.28% | AUC: 0.6378
# Epoch  90 | Train Loss: 0.032222 | Loss Δ: +0.52% | AUC: 0.6403
# Epoch  91 | Train Loss: 0.032062 | Loss Δ: +0.50% | AUC: 0.6382
# Epoch  92 | Train Loss: 0.031942 | Loss Δ: +0.37% | AUC: 0.6336
# Epoch  93 | Train Loss: 0.031816 | Loss Δ: +0.40% | AUC: 0.6424
# Epoch  94 | Train Loss: 0.031929 | Loss Δ: -0.36% | AUC: 0.6433
# Epoch  95 | Train Loss: 0.031836 | Loss Δ: +0.29% | AUC: 0.6399
# Epoch  96 | Train Loss: 0.031609 | Loss Δ: +0.71% | AUC: 0.6529
# Epoch  97 | Train Loss: 0.031416 | Loss Δ: +0.61% | AUC: 0.6465
# Epoch  98 | Train Loss: 0.031322 | Loss Δ: +0.30% | AUC: 0.6456
# Epoch  99 | Train Loss: 0.031242 | Loss Δ: +0.26% | AUC: 0.6597
# Epoch 100 | Train Loss: 0.031067 | Loss Δ: +0.56% | AUC: 0.6453
# Epoch 101 | Train Loss: 0.031050 | Loss Δ: +0.06% | AUC: 0.6672
# Epoch 102 | Train Loss: 0.030979 | Loss Δ: +0.23% | AUC: 0.6562
# Epoch 103 | Train Loss: 0.030839 | Loss Δ: +0.45% | AUC: 0.6611
# Epoch 104 | Train Loss: 0.030995 | Loss Δ: -0.50% | AUC: 0.6366
# Epoch 105 | Train Loss: 0.031377 | Loss Δ: -1.23% | AUC: 0.6683
# Epoch 106 | Train Loss: 0.031118 | Loss Δ: +0.82% | AUC: 0.6523
# Epoch 107 | Train Loss: 0.030641 | Loss Δ: +1.53% | AUC: 0.6713
# Epoch 108 | Train Loss: 0.030302 | Loss Δ: +1.11% | AUC: 0.6647
# Epoch 109 | Train Loss: 0.030001 | Loss Δ: +0.99% | AUC: 0.6781
# Epoch 110 | Train Loss: 0.029755 | Loss Δ: +0.82% | AUC: 0.6719
# Epoch 111 | Train Loss: 0.029633 | Loss Δ: +0.41% | AUC: 0.6774
# Epoch 112 | Train Loss: 0.029443 | Loss Δ: +0.64% | AUC: 0.6876
# Epoch 113 | Train Loss: 0.029272 | Loss Δ: +0.58% | AUC: 0.6875
# Epoch 114 | Train Loss: 0.029034 | Loss Δ: +0.82% | AUC: 0.6890
# Epoch 115 | Train Loss: 0.028875 | Loss Δ: +0.55% | AUC: 0.6907
# Epoch 116 | Train Loss: 0.028822 | Loss Δ: +0.18% | AUC: 0.6827
# Epoch 117 | Train Loss: 0.028828 | Loss Δ: -0.02% | AUC: 0.6858
# Epoch 118 | Train Loss: 0.028749 | Loss Δ: +0.27% | AUC: 0.6911
# Epoch 119 | Train Loss: 0.028704 | Loss Δ: +0.15% | AUC: 0.6811
# Epoch 120 | Train Loss: 0.028559 | Loss Δ: +0.51% | AUC: 0.6908
# Epoch 121 | Train Loss: 0.028356 | Loss Δ: +0.71% | AUC: 0.6916
# Epoch 122 | Train Loss: 0.028120 | Loss Δ: +0.83% | AUC: 0.7011
# Epoch 123 | Train Loss: 0.028110 | Loss Δ: +0.03% | AUC: 0.7004
# Epoch 124 | Train Loss: 0.027907 | Loss Δ: +0.72% | AUC: 0.7035
# Epoch 125 | Train Loss: 0.027567 | Loss Δ: +1.22% | AUC: 0.7020
# Epoch 126 | Train Loss: 0.027541 | Loss Δ: +0.10% | AUC: 0.7008
# Epoch 127 | Train Loss: 0.027382 | Loss Δ: +0.58% | AUC: 0.7087
# Epoch 128 | Train Loss: 0.027155 | Loss Δ: +0.83% | AUC: 0.7184
# Epoch 129 | Train Loss: 0.027007 | Loss Δ: +0.55% | AUC: 0.7126
# Epoch 130 | Train Loss: 0.026900 | Loss Δ: +0.40% | AUC: 0.7179
# Epoch 131 | Train Loss: 0.026759 | Loss Δ: +0.52% | AUC: 0.7194
# Epoch 132 | Train Loss: 0.026673 | Loss Δ: +0.32% | AUC: 0.7245
# Epoch 133 | Train Loss: 0.026498 | Loss Δ: +0.66% | AUC: 0.7268
# Epoch 134 | Train Loss: 0.026321 | Loss Δ: +0.67% | AUC: 0.7250
# Epoch 135 | Train Loss: 0.026350 | Loss Δ: -0.11% | AUC: 0.7193
# Epoch 136 | Train Loss: 0.026328 | Loss Δ: +0.09% | AUC: 0.7192
# Epoch 137 | Train Loss: 0.026205 | Loss Δ: +0.46% | AUC: 0.7300
# Epoch 138 | Train Loss: 0.025922 | Loss Δ: +1.08% | AUC: 0.7288
# Epoch 139 | Train Loss: 0.025722 | Loss Δ: +0.77% | AUC: 0.7333
# Epoch 140 | Train Loss: 0.025586 | Loss Δ: +0.53% | AUC: 0.7337
# Epoch 141 | Train Loss: 0.025511 | Loss Δ: +0.29% | AUC: 0.7251
# Epoch 142 | Train Loss: 0.025393 | Loss Δ: +0.46% | AUC: 0.7233
# Epoch 143 | Train Loss: 0.025478 | Loss Δ: -0.34% | AUC: 0.7355
# Epoch 144 | Train Loss: 0.025314 | Loss Δ: +0.65% | AUC: 0.7376
# Epoch 145 | Train Loss: 0.025172 | Loss Δ: +0.56% | AUC: 0.7466
# Epoch 146 | Train Loss: 0.024854 | Loss Δ: +1.27% | AUC: 0.7516
# Epoch 147 | Train Loss: 0.024484 | Loss Δ: +1.49% | AUC: 0.7464
# Epoch 148 | Train Loss: 0.024375 | Loss Δ: +0.45% | AUC: 0.7516
# Epoch 149 | Train Loss: 0.024388 | Loss Δ: -0.05% | AUC: 0.7497
# Epoch 150 | Train Loss: 0.024500 | Loss Δ: -0.46% | AUC: 0.7516
# Epoch 151 | Train Loss: 0.024079 | Loss Δ: +1.72% | AUC: 0.7613
# Epoch 152 | Train Loss: 0.023844 | Loss Δ: +0.97% | AUC: 0.7663
# Epoch 153 | Train Loss: 0.023739 | Loss Δ: +0.44% | AUC: 0.7669
# Epoch 154 | Train Loss: 0.023555 | Loss Δ: +0.77% | AUC: 0.7610
# Epoch 155 | Train Loss: 0.023353 | Loss Δ: +0.86% | AUC: 0.7641
# Epoch 156 | Train Loss: 0.023380 | Loss Δ: -0.12% | AUC: 0.7716
# Epoch 157 | Train Loss: 0.023289 | Loss Δ: +0.39% | AUC: 0.7801
# Epoch 158 | Train Loss: 0.023019 | Loss Δ: +1.16% | AUC: 0.7825
# Epoch 159 | Train Loss: 0.022828 | Loss Δ: +0.83% | AUC: 0.7723
# Epoch 160 | Train Loss: 0.022695 | Loss Δ: +0.58% | AUC: 0.7870
# Epoch 161 | Train Loss: 0.022539 | Loss Δ: +0.69% | AUC: 0.7892
# Epoch 162 | Train Loss: 0.022471 | Loss Δ: +0.30% | AUC: 0.7939
# Epoch 163 | Train Loss: 0.022063 | Loss Δ: +1.81% | AUC: 0.7967
# Epoch 164 | Train Loss: 0.021840 | Loss Δ: +1.01% | AUC: 0.7970
# Epoch 165 | Train Loss: 0.021762 | Loss Δ: +0.36% | AUC: 0.8021
# Epoch 166 | Train Loss: 0.021663 | Loss Δ: +0.46% | AUC: 0.8019
# Epoch 167 | Train Loss: 0.021454 | Loss Δ: +0.96% | AUC: 0.8023
# Epoch 168 | Train Loss: 0.021410 | Loss Δ: +0.21% | AUC: 0.8009
# Epoch 169 | Train Loss: 0.021422 | Loss Δ: -0.06% | AUC: 0.8055
# Epoch 170 | Train Loss: 0.021489 | Loss Δ: -0.31% | AUC: 0.7945
# Epoch 171 | Train Loss: 0.021681 | Loss Δ: -0.89% | AUC: 0.8068
# Epoch 172 | Train Loss: 0.021365 | Loss Δ: +1.46% | AUC: 0.8149
# Epoch 173 | Train Loss: 0.021264 | Loss Δ: +0.47% | AUC: 0.8132
# Epoch 174 | Train Loss: 0.021083 | Loss Δ: +0.85% | AUC: 0.8043
# Epoch 175 | Train Loss: 0.020846 | Loss Δ: +1.12% | AUC: 0.8111
# Epoch 176 | Train Loss: 0.020569 | Loss Δ: +1.33% | AUC: 0.8184
# Epoch 177 | Train Loss: 0.020905 | Loss Δ: -1.63% | AUC: 0.8230
# Epoch 178 | Train Loss: 0.020919 | Loss Δ: -0.07% | AUC: 0.8087
# Epoch 179 | Train Loss: 0.020795 | Loss Δ: +0.59% | AUC: 0.8192
# Epoch 180 | Train Loss: 0.020443 | Loss Δ: +1.70% | AUC: 0.8183
# Epoch 181 | Train Loss: 0.020318 | Loss Δ: +0.61% | AUC: 0.8282
# Epoch 182 | Train Loss: 0.020063 | Loss Δ: +1.25% | AUC: 0.8332
# Epoch 183 | Train Loss: 0.019785 | Loss Δ: +1.39% | AUC: 0.8352
# Epoch 184 | Train Loss: 0.019473 | Loss Δ: +1.58% | AUC: 0.8337
# Epoch 185 | Train Loss: 0.019206 | Loss Δ: +1.37% | AUC: 0.8377
# Epoch 186 | Train Loss: 0.019281 | Loss Δ: -0.39% | AUC: 0.8373
# Epoch 187 | Train Loss: 0.019341 | Loss Δ: -0.31% | AUC: 0.8355
# Epoch 188 | Train Loss: 0.018998 | Loss Δ: +1.78% | AUC: 0.8396
# Epoch 189 | Train Loss: 0.018813 | Loss Δ: +0.97% | AUC: 0.8426
# Epoch 190 | Train Loss: 0.018654 | Loss Δ: +0.85% | AUC: 0.8463
# Epoch 191 | Train Loss: 0.018442 | Loss Δ: +1.14% | AUC: 0.8450
# Epoch 192 | Train Loss: 0.018356 | Loss Δ: +0.47% | AUC: 0.8447
# Epoch 193 | Train Loss: 0.018343 | Loss Δ: +0.07% | AUC: 0.8404
# Epoch 194 | Train Loss: 0.018361 | Loss Δ: -0.10% | AUC: 0.8449
# Epoch 195 | Train Loss: 0.018313 | Loss Δ: +0.26% | AUC: 0.8413
# Epoch 196 | Train Loss: 0.018236 | Loss Δ: +0.42% | AUC: 0.8537
# Epoch 197 | Train Loss: 0.018200 | Loss Δ: +0.20% | AUC: 0.8537
# Epoch 198 | Train Loss: 0.018054 | Loss Δ: +0.80% | AUC: 0.8562
# Epoch 199 | Train Loss: 0.017887 | Loss Δ: +0.92% | AUC: 0.8554
# Epoch 200 | Train Loss: 0.017908 | Loss Δ: -0.12% | AUC: 0.8464
# Epoch 201 | Train Loss: 0.017842 | Loss Δ: +0.37% | AUC: 0.8547
# Epoch 202 | Train Loss: 0.017662 | Loss Δ: +1.01% | AUC: 0.8543
# Epoch 203 | Train Loss: 0.017790 | Loss Δ: -0.72% | AUC: 0.8600
# Epoch 204 | Train Loss: 0.017600 | Loss Δ: +1.07% | AUC: 0.8586
# Epoch 205 | Train Loss: 0.017397 | Loss Δ: +1.15% | AUC: 0.8587
# Epoch 206 | Train Loss: 0.017273 | Loss Δ: +0.71% | AUC: 0.8635
# Epoch 207 | Train Loss: 0.016944 | Loss Δ: +1.90% | AUC: 0.8652
# Epoch 208 | Train Loss: 0.016703 | Loss Δ: +1.42% | AUC: 0.8718
# Epoch 209 | Train Loss: 0.016598 | Loss Δ: +0.63% | AUC: 0.8698
# Epoch 210 | Train Loss: 0.016536 | Loss Δ: +0.38% | AUC: 0.8730
# Epoch 211 | Train Loss: 0.016466 | Loss Δ: +0.42% | AUC: 0.8711
# Epoch 212 | Train Loss: 0.016451 | Loss Δ: +0.09% | AUC: 0.8733
# Epoch 213 | Train Loss: 0.016307 | Loss Δ: +0.88% | AUC: 0.8724
# Epoch 214 | Train Loss: 0.016235 | Loss Δ: +0.44% | AUC: 0.8759
# Epoch 215 | Train Loss: 0.016315 | Loss Δ: -0.49% | AUC: 0.8723
# Epoch 216 | Train Loss: 0.016292 | Loss Δ: +0.14% | AUC: 0.8760
# Epoch 217 | Train Loss: 0.016143 | Loss Δ: +0.91% | AUC: 0.8749
# Epoch 218 | Train Loss: 0.015973 | Loss Δ: +1.05% | AUC: 0.8813
# Epoch 219 | Train Loss: 0.015900 | Loss Δ: +0.46% | AUC: 0.8804
# Epoch 220 | Train Loss: 0.015890 | Loss Δ: +0.06% | AUC: 0.8814
# Epoch 221 | Train Loss: 0.015924 | Loss Δ: -0.22% | AUC: 0.8751
# Epoch 222 | Train Loss: 0.016187 | Loss Δ: -1.65% | AUC: 0.8690
# Epoch 223 | Train Loss: 0.016076 | Loss Δ: +0.68% | AUC: 0.8843
# Epoch 224 | Train Loss: 0.015753 | Loss Δ: +2.01% | AUC: 0.8799
# Epoch 225 | Train Loss: 0.015420 | Loss Δ: +2.11% | AUC: 0.8831
# Epoch 226 | Train Loss: 0.015339 | Loss Δ: +0.52% | AUC: 0.8831
# Epoch 227 | Train Loss: 0.015244 | Loss Δ: +0.62% | AUC: 0.8864
# Epoch 228 | Train Loss: 0.015289 | Loss Δ: -0.30% | AUC: 0.8833
# Epoch 229 | Train Loss: 0.015178 | Loss Δ: +0.73% | AUC: 0.8909
# Epoch 230 | Train Loss: 0.015076 | Loss Δ: +0.67% | AUC: 0.8893
# Epoch 231 | Train Loss: 0.014849 | Loss Δ: +1.50% | AUC: 0.8884
# Epoch 232 | Train Loss: 0.014650 | Loss Δ: +1.34% | AUC: 0.8957
# Epoch 233 | Train Loss: 0.014538 | Loss Δ: +0.76% | AUC: 0.8955
# Epoch 234 | Train Loss: 0.014508 | Loss Δ: +0.21% | AUC: 0.8973
# Epoch 235 | Train Loss: 0.014612 | Loss Δ: -0.72% | AUC: 0.8955
# Epoch 236 | Train Loss: 0.014513 | Loss Δ: +0.68% | AUC: 0.8972
# Epoch 237 | Train Loss: 0.014539 | Loss Δ: -0.18% | AUC: 0.8952
# Epoch 238 | Train Loss: 0.014802 | Loss Δ: -1.80% | AUC: 0.8945
# Epoch 239 | Train Loss: 0.014843 | Loss Δ: -0.28% | AUC: 0.8931
# Epoch 240 | Train Loss: 0.014687 | Loss Δ: +1.05% | AUC: 0.8977
# Epoch 241 | Train Loss: 0.014503 | Loss Δ: +1.25% | AUC: 0.8923
# Epoch 242 | Train Loss: 0.014428 | Loss Δ: +0.52% | AUC: 0.8993
# Epoch 243 | Train Loss: 0.014342 | Loss Δ: +0.60% | AUC: 0.8994
# Epoch 244 | Train Loss: 0.014244 | Loss Δ: +0.69% | AUC: 0.8982
# Epoch 245 | Train Loss: 0.014176 | Loss Δ: +0.48% | AUC: 0.9045
# Epoch 246 | Train Loss: 0.014119 | Loss Δ: +0.40% | AUC: 0.8976
# Epoch 247 | Train Loss: 0.014034 | Loss Δ: +0.60% | AUC: 0.9061
# Epoch 248 | Train Loss: 0.013773 | Loss Δ: +1.86% | AUC: 0.9013
# Epoch 249 | Train Loss: 0.013611 | Loss Δ: +1.17% | AUC: 0.9097
# Epoch 250 | Train Loss: 0.013414 | Loss Δ: +1.45% | AUC: 0.9110
# Epoch 251 | Train Loss: 0.013291 | Loss Δ: +0.91% | AUC: 0.9091
# Epoch 252 | Train Loss: 0.013194 | Loss Δ: +0.73% | AUC: 0.9120
# Epoch 253 | Train Loss: 0.013102 | Loss Δ: +0.69% | AUC: 0.9119
# Epoch 254 | Train Loss: 0.013068 | Loss Δ: +0.26% | AUC: 0.9100
# Epoch 255 | Train Loss: 0.013087 | Loss Δ: -0.15% | AUC: 0.9103
# Epoch 256 | Train Loss: 0.012995 | Loss Δ: +0.70% | AUC: 0.9134
# Epoch 257 | Train Loss: 0.012997 | Loss Δ: -0.02% | AUC: 0.9104
# Epoch 258 | Train Loss: 0.012985 | Loss Δ: +0.10% | AUC: 0.9110
# Epoch 259 | Train Loss: 0.012949 | Loss Δ: +0.28% | AUC: 0.9126
# Epoch 260 | Train Loss: 0.012867 | Loss Δ: +0.63% | AUC: 0.9175

# %%
# %cd ..
# Out:
# /content/cs421pain

# %% [markdown]
# save weights

# %%
import datetime
import os

cwd = os.getcwd()
save_dir = "UNSAVED"

if LOCAL_TERMINAL:
    save_dir = os.path.abspath(os.path.join(cwd, "weights"))
if COLAB_TERMINAL:
    save_dir = os.path.abspath(os.path.join(cwd, "Strategies", "Larry", "weights"))


timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
save_dir = os.path.join(save_dir, f"autoencoder_weights_{timestamp}.pth")


torch.save(model.state_dict(), save_dir)
print(f"[{timestamp}] Model weights saved to: {save_dir}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_878/3209980096.py in <cell line: 0>()
#      15
#      16
# ---> 17 torch.save(model.state_dict(), save_dir)
#      18 print(f"[{timestamp}] Model weights saved to: {save_dir}")
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     974
#     975     if _use_new_zipfile_serialization:
# --> 976         with _open_zipfile_writer(f) as opened_zipfile:
#     977             _save(
#     978                 obj,
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in _open_zipfile_writer(name_or_buffer)
#     836     else:
#     837         container = _open_zipfile_writer_buffer
# --> 838     return container(name_or_buffer)  # type: ignore[arg-type]
#     839
#     840
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in __init__(self, name)
#     800         else:
#     801             super().__init__(
# --> 802                 torch._C.PyTorchFileWriter(
#     803                     self.name, get_crc32_options(), _get_storage_alignment()
#     804                 )
#
# RuntimeError: Parent directory /content/cs421pain/cs421pain/Strategies/Larry/weights does not exist.

# %% [markdown]
# save config

# %%
import json

# Best case: your model stores these as attributes

model = Autoencoder(layer_sizes=[1000, 500, 250, 125, 64]).to(device)

model_config = {"layer_sizes": getattr(model, "layer_sizes", None)}

print(model_config)

config_path = os.path.join(save_dir, "model_config.json")
with open(config_path, "w") as f:
    json.dump(model_config, f, indent=2)

print("Saved config to:", config_path)
# Out:
# {'layer_sizes': None}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_878/32225646.py in <cell line: 0>()
#      10
#      11 config_path = os.path.join(save_path, "model_config.json")
# ---> 12 with open(config_path, "w") as f:
#      13     json.dump(model_config, f, indent=2)
#      14
#
# FileNotFoundError: [Errno 2] No such file or directory: 'UNSAVED/model_config.json'

# %%
model = Autoencoder(layer_sizes=[1000, 500, 250, 125, 64]).to(device)
model.load_state_dict(torch.load(save_dir, map_location=device))
model.eval()
